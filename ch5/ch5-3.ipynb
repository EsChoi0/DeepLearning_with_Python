# %%
from tensorflow.keras.datasets import mnist
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28*28))
train_images = train_images.astype("float32")/255

model = keras.Sequential([
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax")
    ])
model.compile(optimizer=keras.optimizers.RMSprop(1.),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
model.fit(train_images, train_labels,
          epochs=10,
          batch_size=128,
          validation_split=0.2)
# Out:
# Epoch 1/10
# 375/375 [==============================] - 1s 3ms/step - loss: 761.1713 - accuracy: 0.3535 - val_loss: 2.1418 - val_accuracy: 0.2380
# Epoch 2/10
# 375/375 [==============================] - 1s 3ms/step - loss: 3.7193 - accuracy: 0.2415 - val_loss: 2.0924 - val_accuracy: 0.2150
# Epoch 3/10
# 375/375 [==============================] - 1s 3ms/step - loss: 3.7605 - accuracy: 0.2617 - val_loss: 2.0983 - val_accuracy: 0.2565
# Epoch 4/10
# 375/375 [==============================] - 1s 3ms/step - loss: 2.6399 - accuracy: 0.2682 - val_loss: 2.6849 - val_accuracy: 0.2338
# Epoch 5/10
# 375/375 [==============================] - 1s 3ms/step - loss: 2.6050 - accuracy: 0.2579 - val_loss: 2.1428 - val_accuracy: 0.2750
# Epoch 6/10
# 375/375 [==============================] - 1s 3ms/step - loss: 2.5419 - accuracy: 0.2368 - val_loss: 2.3337 - val_accuracy: 0.2425
# Epoch 7/10
# 375/375 [==============================] - 1s 3ms/step - loss: 3.1069 - accuracy: 0.2681 - val_loss: 2.0856 - val_accuracy: 0.3015
# Epoch 8/10
# 375/375 [==============================] - 1s 3ms/step - loss: 2.8992 - accuracy: 0.2750 - val_loss: 2.1540 - val_accuracy: 0.2504
# Epoch 9/10
# 375/375 [==============================] - 1s 3ms/step - loss: 2.4857 - accuracy: 0.2697 - val_loss: 2.1058 - val_accuracy: 0.2413
# Epoch 10/10
# 375/375 [==============================] - 1s 3ms/step - loss: 2.7663 - accuracy: 0.3042 - val_loss: 2.1208 - val_accuracy: 0.2907

# %%
model = keras.Sequential([
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax")
    ])
model.compile(optimizer=keras.optimizers.RMSprop(1e-2),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
model.fit(train_images, train_labels,
          epochs=10,
          batch_size=128,
          validation_split=0.2)
# Out:
# Epoch 1/10
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3673 - accuracy: 0.9126 - val_loss: 0.1448 - val_accuracy: 0.9613
# Epoch 2/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1426 - accuracy: 0.9624 - val_loss: 0.1451 - val_accuracy: 0.9661
# Epoch 3/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1111 - accuracy: 0.9726 - val_loss: 0.1752 - val_accuracy: 0.9689
# Epoch 4/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1033 - accuracy: 0.9775 - val_loss: 0.1960 - val_accuracy: 0.9694
# Epoch 5/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0874 - accuracy: 0.9819 - val_loss: 0.2047 - val_accuracy: 0.9693
# Epoch 6/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0818 - accuracy: 0.9839 - val_loss: 0.1877 - val_accuracy: 0.9740
# Epoch 7/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0746 - accuracy: 0.9858 - val_loss: 0.2351 - val_accuracy: 0.9728
# Epoch 8/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0595 - accuracy: 0.9885 - val_loss: 0.2697 - val_accuracy: 0.9741
# Epoch 9/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0610 - accuracy: 0.9891 - val_loss: 0.2507 - val_accuracy: 0.9767
# Epoch 10/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0531 - accuracy: 0.9904 - val_loss: 0.3573 - val_accuracy: 0.9700

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# %%
(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28*28))
train_images = train_images.astype("float32")/255

model = keras.Sequential([layers.Dense(10, activation="softmax")])
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
history_small_model = model.fit(
    train_images, train_labels,
    epochs=20,
    batch_size=128,
    validation_split=0.2
)

val_loss = history_small_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(epochs, val_loss, "r-", # "red, -실선"
         label="Validation loss")
plt.title("Effect of model size on validation loss")
plt.xlabel("Epochs")
plt.ylabel("loss")
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.6691 - accuracy: 0.8369 - val_loss: 0.3566 - val_accuracy: 0.9059
# Epoch 2/20
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3507 - accuracy: 0.9038 - val_loss: 0.3080 - val_accuracy: 0.9146
# Epoch 3/20
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3153 - accuracy: 0.9121 - val_loss: 0.2901 - val_accuracy: 0.9187
# Epoch 4/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2989 - accuracy: 0.9171 - val_loss: 0.2814 - val_accuracy: 0.9212
# Epoch 5/20
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2896 - accuracy: 0.9197 - val_loss: 0.2764 - val_accuracy: 0.9237
# Epoch 6/20
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2834 - accuracy: 0.9212 - val_loss: 0.2722 - val_accuracy: 0.9250
# Epoch 7/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2777 - accuracy: 0.9227 - val_loss: 0.2703 - val_accuracy: 0.9268
# Epoch 8/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2742 - accuracy: 0.9239 - val_loss: 0.2664 - val_accuracy: 0.9278
# Epoch 9/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2711 - accuracy: 0.9248 - val_loss: 0.2662 - val_accuracy: 0.9277
# Epoch 10/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2685 - accuracy: 0.9252 - val_loss: 0.2643 - val_accuracy: 0.9284
# Epoch 11/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2666 - accuracy: 0.9266 - val_loss: 0.2638 - val_accuracy: 0.9290
# Epoch 12/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2648 - accuracy: 0.9274 - val_loss: 0.2626 - val_accuracy: 0.9283
# Epoch 13/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2629 - accuracy: 0.9275 - val_loss: 0.2617 - val_accuracy: 0.9305
# Epoch 14/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2615 - accuracy: 0.9285 - val_loss: 0.2605 - val_accuracy: 0.9305
# Epoch 15/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2603 - accuracy: 0.9283 - val_loss: 0.2618 - val_accuracy: 0.9298
# Epoch 16/20
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2594 - accuracy: 0.9286 - val_loss: 0.2623 - val_accuracy: 0.9295
# Epoch 17/20
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2582 - accuracy: 0.9292 - val_loss: 0.2612 - val_accuracy: 0.9306
# Epoch 18/20
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2572 - accuracy: 0.9305 - val_loss: 0.2612 - val_accuracy: 0.9302
# Epoch 19/20
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2562 - accuracy: 0.9303 - val_loss: 0.2622 - val_accuracy: 0.9305
# Epoch 20/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2555 - accuracy: 0.9305 - val_loss: 0.2621 - val_accuracy: 0.9309

# %%
model = keras.Sequential([
    layers.Dense(96, activation="relu"),
    layers.Dense(96, activation="relu"),
    layers.Dense(10, activation="softmax")
])

model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
history_large_model = model.fit(
    train_images, train_labels,
    epochs=20,
    batch_size=128,
    validation_split=0.2
)
# Out:
# Epoch 1/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3600 - accuracy: 0.8962 - val_loss: 0.1889 - val_accuracy: 0.9462
# Epoch 2/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1627 - accuracy: 0.9513 - val_loss: 0.1404 - val_accuracy: 0.9597
# Epoch 3/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1149 - accuracy: 0.9659 - val_loss: 0.1122 - val_accuracy: 0.9671
# Epoch 4/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0879 - accuracy: 0.9736 - val_loss: 0.1050 - val_accuracy: 0.9699
# Epoch 5/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0713 - accuracy: 0.9782 - val_loss: 0.1014 - val_accuracy: 0.9706
# Epoch 6/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0575 - accuracy: 0.9825 - val_loss: 0.0982 - val_accuracy: 0.9734
# Epoch 7/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0488 - accuracy: 0.9854 - val_loss: 0.1113 - val_accuracy: 0.9692
# Epoch 8/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0405 - accuracy: 0.9873 - val_loss: 0.0952 - val_accuracy: 0.9752
# Epoch 9/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0343 - accuracy: 0.9895 - val_loss: 0.1092 - val_accuracy: 0.9707
# Epoch 10/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0280 - accuracy: 0.9918 - val_loss: 0.1088 - val_accuracy: 0.9735
# Epoch 11/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0251 - accuracy: 0.9924 - val_loss: 0.1044 - val_accuracy: 0.9751
# Epoch 12/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0212 - accuracy: 0.9932 - val_loss: 0.1129 - val_accuracy: 0.9743
# Epoch 13/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0178 - accuracy: 0.9941 - val_loss: 0.1111 - val_accuracy: 0.9751
# Epoch 14/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0148 - accuracy: 0.9954 - val_loss: 0.1298 - val_accuracy: 0.9736
# Epoch 15/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0130 - accuracy: 0.9962 - val_loss: 0.1398 - val_accuracy: 0.9716
# Epoch 16/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0106 - accuracy: 0.9969 - val_loss: 0.1303 - val_accuracy: 0.9755
# Epoch 17/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0100 - accuracy: 0.9971 - val_loss: 0.1323 - val_accuracy: 0.9753
# Epoch 18/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0081 - accuracy: 0.9977 - val_loss: 0.1463 - val_accuracy: 0.9748
# Epoch 19/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.1422 - val_accuracy: 0.9757
# Epoch 20/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0063 - accuracy: 0.9978 - val_loss: 0.1459 - val_accuracy: 0.9748

# %%
val_loss = history_large_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(epochs, val_loss, "b-", # "blue, -실선"
         label="Validation loss")
plt.title("Effect of model size on validation loss")
plt.xlabel("Epochs")
plt.ylabel("loss")
plt.legend()
plt.show()
